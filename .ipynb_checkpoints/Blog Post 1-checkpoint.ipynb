# %% [markdown]
# #### Hello everyone, and welcome to my first blog post!
#
# The purpose of this blog is to document my progress on a self-designed school project at the University of New Hampshire where I will examining [tweets](https://about.twitter.com/en_us/values/elections-integrity.html#data) identified as being part of the Russian disinformation campaign during the 2016 US presidential election. This data was released in October 2018 by Twitter and includes 1.24 GB of tweet information and 296 GB of image, GIF, video, and periscope broadcast data.
#
# Since this data was released, a number of reports have been published examining the methods of the Internet Research Agency, an organization run by a close Putin ally which is believed to be behind the  aforementioned disinformation campaign on various social media platforms, including Twitter. These reports include two commissioned by the Senate Intelligence Committee: [*The IRA Social Media and Political Polarization in the United States, 2012-2018*](https://int.nyt.com/data/documenthelper/534-oxford-russia-internet-research-agency/c6588b4a7b940c551c38/optimized/full.pdf#page=1) by the Computational Propaganda Research Project at the Oxford Internet Institute, and [*The Tactics and Tropes of the Internet Research Agency*](https://int.nyt.com/data/documenthelper/533-read-report-internet-research-agency/7871ea6d5b7bedafbf19/optimized/full.pdf#page=1) by New Knowledge. For the most part, I will be attempting to replicate the findings of these and other reports as I learn more about different data science techniques including Natural Language Processing, Network Analysis, and Image Processing.
#
# With that being said, let's get started with some EDA!

# %%
import numpy as np
import pandas as pd
import re
pd.set_option('display.max_columns', None)

import os
os.chdir('/Users/benjaminforleo/Box/spring_project/')

# %%
df = pd.read_csv('ira_tweets_csv_hashed.csv', low_memory = False)

# %%
print(df.shape)
print("")
print(df.columns)
# Out:
# (9041308, 31)
#
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_language',
#        'tweet_text', 'tweet_time', 'tweet_client_name', 'in_reply_to_tweetid',
#        'in_reply_to_userid', 'quoted_tweet_tweetid', 'is_retweet',
#        'retweet_userid', 'retweet_tweetid', 'latitude', 'longitude',
#        'quote_count', 'reply_count', 'like_count', 'retweet_count', 'hashtags',
#        'urls', 'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
df.iloc[:,7:].head()
# Out:
#    follower_count  following_count account_creation_date account_language  \
# 0             132              120            2013-12-07               ru
# 1              74                8            2014-03-15               en
# 2             165              454            2014-04-29               en
# 3             165              454            2014-04-29               en
# 4            4430             4413            2012-02-25               ru
#
#   tweet_language                                         tweet_text  \
# 0             ru  RT @ruopentwit: ⚡️У НАС НОВОЕ ВИДЕО! Американе...
# 1             ru       Серебром отколоколило http://t.co/Jaa4v4IFpM
# 2             bg        @kpru С-300 в Иране https://t.co/elnu3qLUW7
# 3             ru  Предлагаю судить их за поддержку нацизма, т.к....
# 4             bg  Предостережение американского дипломата https:...
#
#          tweet_time   tweet_client_name  in_reply_to_tweetid  \
# 0  2017-06-22 16:03           TweetDeck                  NaN
# 1  2014-07-24 19:20         generationπ                  NaN
# 2  2016-04-11 09:20           TweetDeck         7.194399e+17
# 3  2014-11-22 15:28  Twitter Web Client                  NaN
# 4  2017-03-13 22:08  Twitter Web Client                  NaN
#
#   in_reply_to_userid  quoted_tweet_tweetid  is_retweet retweet_userid  \
# 0                NaN                   NaN        True     2572896396
# 1                NaN                   NaN       False            NaN
# 2           40807205                   NaN       False            NaN
# 3                NaN                   NaN       False            NaN
# 4                NaN                   NaN       False            NaN
#
#    retweet_tweetid  latitude  longitude  quote_count  reply_count  like_count  \
# 0     8.779172e+17       NaN        NaN          0.0          0.0         0.0
# 1              NaN       NaN        NaN          0.0          0.0         0.0
# 2              NaN       NaN        NaN          0.0          0.0         0.0
# 3              NaN       NaN        NaN          0.0          0.0         0.0
# 4              NaN       NaN        NaN          0.0          0.0         3.0
#
#    retweet_count    hashtags                                           urls  \
# 0            0.0          []   [http://ru-open.livejournal.com/374284.html]
# 1            0.0         NaN  [http://pyypilg33.livejournal.com/11069.html]
# 2            0.0          []  [https://www.youtube.com/watch?v=9GvpImWxTJc]
# 3            0.0  [STOPNazi]                                            NaN
# 4            4.0          []                        [https://goo.gl/fBp94X]
#
#   user_mentions poll_choices
# 0  [2572896396]          NaN
# 1           NaN          NaN
# 2    [40807205]          NaN
# 3           NaN          NaN
# 4           NaN          NaN

# %% [markdown]
# It looks like many of these tweets are in Russian. For the natural language processing portion of the project, I'll work entirely with english language tweets.

# %%
en_tweets = df[df.tweet_language == 'en']

# %%
en_tweets.shape
# Out:
# (3261931, 31)

# %%
en_tweets.iloc[:,7:].head()
# Out:
#     follower_count  following_count account_creation_date account_language  \
# 8              696              863            2013-08-06               en
# 10             103              218            2014-03-24               en
# 11             103              218            2014-03-24               en
# 12             103              218            2014-03-24               en
# 32              63               77            2014-05-23               en
#
#    tweet_language                                         tweet_text  \
# 8              en  As sun and cloud give way to moon and shadow, ...
# 10             en             Down in the comfort of strangers, I...
# 11             en                Im laughing more than i should #USA
# 12             en                       No, I'm not saying I'm sorry
# 32             en                      Laugh it all off in your face
#
#           tweet_time   tweet_client_name  in_reply_to_tweetid  \
# 8   2015-02-16 16:19  Twitter Web Client                  NaN
# 10  2014-07-28 23:02            vavilonX                  NaN
# 11  2014-07-28 09:24            vavilonX                  NaN
# 12  2014-08-08 00:43            vavilonX                  NaN
# 32  2014-08-17 10:46            vavilonX                  NaN
#
#    in_reply_to_userid  quoted_tweet_tweetid  is_retweet retweet_userid  \
# 8                 NaN                   NaN       False            NaN
# 10                NaN                   NaN       False            NaN
# 11                NaN                   NaN       False            NaN
# 12                NaN                   NaN       False            NaN
# 32                NaN                   NaN       False            NaN
#
#     retweet_tweetid  latitude  longitude  quote_count  reply_count  \
# 8               NaN       NaN        NaN          0.0          0.0
# 10              NaN       NaN        NaN          0.0          0.0
# 11              NaN       NaN        NaN          0.0          0.0
# 12              NaN       NaN        NaN          0.0          0.0
# 32              NaN       NaN        NaN          0.0          0.0
#
#     like_count  retweet_count hashtags urls user_mentions poll_choices
# 8          0.0            0.0      NaN  NaN           NaN          NaN
# 10         0.0            0.0      NaN  NaN           NaN          NaN
# 11         0.0            0.0    [USA]  NaN           NaN          NaN
# 12         0.0            0.0      NaN  NaN           NaN          NaN
# 32         0.0            0.0      NaN  NaN           NaN          NaN

# %% [markdown]
# Great! We've filtered down to tweets containing english text. Let's see how many unique accounts there are from this group.

# %%
print("Number of unique accounts with english text:", len(set(en_tweets.userid)))
# Out:
# Number of unique accounts with english text: 3259

# %% [markdown]
# Interesting! In the coming weeks, I will be digging into natural language processing and trying to find patterns in the text posted by these accounts.
